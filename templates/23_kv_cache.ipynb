# %% [markdown]
# # 🔴 Hard: KV Cache for Attention
#
# Implement **KV Cache** for efficient LLM inference during generation.
#
# KV Cache stores past Key and Value tensors to avoid recomputation:
# - `append(k, v)`: Add new K, V to cache
# - `get()`: Return all cached K, V
# - `clear()`: Reset cache
#
# ### Signature
# ```python
# class KVCache:
#     def __init__(self, num_heads: int, head_dim: int, max_seq_len: int, batch_size: int):
#         ...
#     def append(self, k: torch.Tensor, v: torch.Tensor) -> None:
#         ...
#     def get(self) -> tuple[torch.Tensor, torch.Tensor]:
#         ...
#     def clear(self) -> None:
#         ...
# ```

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class KVCache:
    def __init__(self, num_heads: int, head_dim: int, max_seq_len: int, batch_size: int):
        # ...
        pass
    
    def append(self, k: torch.Tensor, v: torch.Tensor) -> None:
        # k, v: (batch, num_heads, seq_len, head_dim)
        pass
    
    def get(self) -> tuple[torch.Tensor, torch.Tensor]:
        pass
    
    def clear(self) -> None:
        pass

# %%
# 🧪 Test your implementation
cache = KVCache(num_heads=8, head_dim=64, max_seq_len=256, batch_size=2)
k1 = torch.randn(2, 8, 3, 64)
v1 = torch.randn(2, 8, 3, 64)
cache.append(k1, v1)
k, v = cache.get()
print(f"K shape after first append: {k.shape}")
print(f"seq_len: {cache.seq_len}")

# %%
# ✅ SUBMIT
from torch_judge import check
check("kv_cache")
